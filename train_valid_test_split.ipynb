# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshkant/25-short-code-snippets_Python/blob/master/train_valid_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install fast_ml library
! pip install fast_ml --quiet
# Out:
#      |████████████████████████████████| 42 kB 323 kB/s

# %%
# imports
import pandas as pd
from fast_ml.model_development import train_valid_test_split

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/utkarshkant/Datasets-Helper-Functions/main/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
# preview data
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# train, test, validation split
X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(df, 
                                                                            target = 'Churn', 
                                                                            train_size=0.6, 
                                                                            valid_size=0.2, 
                                                                            test_size=0.2)

# reset index
for data in [X_train, y_train, X_valid, y_valid, X_test, y_test]:
    data.reset_index(drop=True, inplace=True)

# %% [markdown]
# - The split datasets retain their original index and resetting it is an optional step.

# %%
# split dataset size
print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4225, 20) (4225,)
# (1409, 20) (1409,)
# (1409, 20) (1409,)

# %%
X_train.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  6281-FKEWS  Female              0      No         No      44           No
# 1  8294-UIMBA  Female              0      No         No      30          Yes
# 2  7858-GTZSP  Female              0      No         No      12          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No           No
# 1                No     Fiber optic             No           No
# 2               Yes     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0              Yes          No         Yes             Yes        One year
# 1               No         Yes         Yes             Yes        One year
# 2               No          No          No             Yes  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           49.05         2265
# 1              Yes  Bank transfer (automatic)           94.40       2638.1
# 2              Yes           Electronic check           86.55       1066.9

# %%
y_train.head(3)
# Out:
# 0    No
# 1    No
# 2    No
# Name: Churn, dtype: object

# %%
X_valid.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  2919-HBCJO  Female              0      No         No       4          Yes
# 1  5656-JAMLX    Male              0      No         No      62          Yes
# 2  0909-SDHNU  Female              0      No        Yes       7           No
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0                No     Fiber optic                   No                  Yes
# 1                No              No  No internet service  No internet service
# 2  No phone service             DSL                  Yes                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No                   No                   No
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                   No  Month-to-month              Yes
# 1  No internet service        Two year               No
# 2                   No  Month-to-month               No
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0  Bank transfer (automatic)           76.65        333.6
# 1  Bank transfer (automatic)           19.85      1253.65
# 2               Mailed check           29.80       201.95

# %%
y_valid.head(3)
# Out:
# 0    Yes
# 1     No
# 2     No
# Name: Churn, dtype: object

# %%
X_test.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  8204-YJCLA    Male              1     Yes        Yes      72           No
# 1  7876-DNYAP  Female              0     Yes        Yes      69          Yes
# 2  6145-NNPNO  Female              0      No         No       1          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0  No phone service             DSL                  Yes                  Yes
# 1                No              No  No internet service  No internet service
# 2                No             DSL                   No                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                  Yes                  Yes                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                  Yes        Two year              Yes
# 1  No internet service        Two year               No
# 2                   No  Month-to-month               No
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0  Bank transfer (automatic)           64.80      4732.35
# 1    Credit card (automatic)           19.80      1436.95
# 2  Bank transfer (automatic)           44.15        44.15

# %%
y_test.head(3)
# Out:
# 0    No
# 1    No
# 2    No
# Name: Churn, dtype: object
